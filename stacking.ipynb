# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn import model_selection, preprocessing, ensemble
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression,LogisticRegression
from numpy import nan
from com_util import *
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) # ingore warnings

# %%
cols = ['brent', 'eurrub', 'usdrub', 'micex_cbi_tr', 'micex_rgbi_tr','micex',  'brent', 'rts', 'oil_urals',
        'balance_trade', 'ppi', 'cpi', 'gdp_quart', 'net_capital_export', 'micex_cbi_tr', 'deposits_rate',
       'gdp_quart_growth', 'mortgage_rate', 'average_provision_of_build_contract_moscow']

# %%
df_train = pd.read_csv("../data/train.csv", parse_dates=['timestamp'])
df_test = pd.read_csv("../data/test.csv", parse_dates=['timestamp'])
df_macro = pd.read_csv("../data/macro.csv", parse_dates=['timestamp'], usecols=['timestamp']+cols)
df_train.head()
# Out:
#    id  timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1 2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2 2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3 2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4 2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5 2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq    ...      cafe_count_5000_price_2500  \
# 0       NaN       NaN    ...                               9
# 1       NaN       NaN    ...                              15
# 2       NaN       NaN    ...                              10
# 3       NaN       NaN    ...                              11
# 4       NaN       NaN    ...                             319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# 1                          3                          0
# 2                          3                          0
# 3                          2                          1
# 4                        108                         17
#
#    big_church_count_5000  church_count_5000  mosque_count_5000  \
# 0                     13                 22                  1
# 1                     15                 29                  1
# 2                     11                 27                  0
# 3                      4                  4                  0
# 4                    135                236                  2
#
#    leisure_count_5000  sport_count_5000  market_count_5000  price_doc
# 0                   0                52                  4    5850000
# 1                  10                66                 14    6000000
# 2                   4                67                 10    5700000
# 3                   0                26                  3   13100000
# 4                  91               195                 14   16331452
#
# [5 rows x 292 columns]

# %%
df_train_loc = pd.read_csv("../data/train_lat_lon.csv")
df_test_loc = pd.read_csv("../data/test_lat_lon.csv")
df_train = df_train.merge(df_train_loc, on='id')
df_train.drop(['key', 'tolerance_m'], axis=1, inplace=True)
df_test = df_test.merge(df_test_loc, on='id')
df_test.drop(['key', 'tolerance_m'], axis=1, inplace=True)

# %%
y_train = df_train['price_doc'].values
id_test = df_test['id']

df_train.drop(['id', 'price_doc'], axis=1, inplace=True)
df_test.drop(['id'], axis=1, inplace=True)

# Build df_all = (df_train+df_test).join(df_macro)
num_train = len(df_train)
df_all = pd.concat([df_train, df_test])
df_all = df_all.merge(df_macro, on='timestamp')

# Add month-year count
month_year = (df_all.timestamp.dt.month + df_all.timestamp.dt.year * 100)
month_year_cnt_map = month_year.value_counts().to_dict()
df_all['month_year_cnt'] = month_year.map(month_year_cnt_map)

# Add week-year count
week_year = (df_all.timestamp.dt.weekofyear + df_all.timestamp.dt.year * 100)
week_year_cnt_map = week_year.value_counts().to_dict()
df_all['week_year_cnt'] = week_year.map(week_year_cnt_map)

# Add month and day-of-week
df_all['month'] = df_all.timestamp.dt.month
df_all['dow'] = df_all.timestamp.dt.dayofweek

print(df_all.shape)
# Out:
# (38133, 313)

# %%
# doing some cleaning of square
df_all['full_sq'].ix[df_all.full_sq > 1000] = nan
df_all['life_sq'].ix[df_all.life_sq > 1000] = nan

df_all['life_sq'].ix[df_all.full_sq < df_all.life_sq] = nan
df_all['life_sq'].ix[df_all.life_sq < 5] = nan
df_all['full_sq'].ix[df_all.full_sq < 5] = nan
df_all['kitch_sq'].ix[df_all.kitch_sq > df_all.life_sq] = nan
# Out:
# /Library/Python/2.7/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# cleaning build_year
df_all['build_year'].ix[df_all.build_year == 20052009] = 2007
df_all['build_year'].ix[df_all.build_year < 1500] = nan
df_all['build_year'].ix[df_all.build_year > 2500] = nan

df_all['state'].ix[df_all.state == 33] = 3

# cleaning floor
df_all['max_floor'].ix[df_all.max_floor == 0] = nan
df_all['floor'].ix[df_all.floor == 0] = nan

# %%
# Add null value counts
df_all['null_count'] = df_all.isnull().sum(axis=1)
# Add apartment name
# df_all['apartment_name'] = df_all['sub_area'] + df_all['metro_km_avto'].astype(str)

# %%
#每个经纬度分类一下（1平方千米一个类）
df_all["jwd_class"]=map(lambda x,y:(int(x*100)%100)*100+(int(-y*100)%100),df_all["lat"].fillna(0),df_all["lon"].fillna(0))
# GroupBy 经纬度
df_all = merge_median(df_all, ["jwd_class"], "full_sq", "fullsq_median_jwd")
df_all = merge_median(df_all, ["jwd_class"], "life_sq", "lifesq_median_jwd")
df_all = merge_median(df_all, ["jwd_class"], "floor", "floor_median_jwd")

# %%
df_all['full_sq_separate'] = df_all['full_sq'].copy()

for i in range(30):
    df_all['full_sq_separate'].ix[(df_all.full_sq > (i+1)*5) & (df_all.full_sq <= ((i+1)*5+5))] = \
    len(df_all['full_sq'].ix[(df_all.full_sq > (i+1)*5) & (df_all.full_sq <= ((i+1)*5+5))])
    
df_all['full_sq_separate'].ix[df_all.full_sq <= 5] = len(df_all['full_sq'].ix[df_all.full_sq <= 5])
df_all['full_sq_separate'].ix[df_all.full_sq <= 5] = len(df_all['full_sq'].ix[df_all.full_sq > 155])

# %%
df_all['life_sq_separate'] = df_all['life_sq'].copy()

for i in range(30):
    df_all['life_sq_separate'].ix[(df_all.life_sq > (i+1)*5) & (df_all.life_sq <= ((i+1)*5+5))] = \
    len(df_all['life_sq'].ix[(df_all.life_sq > (i+1)*5) & (df_all.life_sq <= ((i+1)*5+5))])
    
df_all['life_sq_separate'].ix[df_all.life_sq <= 5] = len(df_all['life_sq'].ix[df_all.life_sq <= 5])
df_all['life_sq_separate'].ix[df_all.life_sq <= 5] = len(df_all['life_sq'].ix[df_all.life_sq > 155])

# %%
# Remove timestamp column (may overfit the model in train)
df_all.drop(['timestamp'], axis=1, inplace=True)
# df_all.drop(['timestamp_macro'], axis=1, inplace=True)

# %%
# Deal with categorical values
df_numeric = df_all.select_dtypes(exclude=['object'])
df_obj = df_all.select_dtypes(include=['object']).copy()

for c in df_obj:
    df_obj[c] = pd.factorize(df_obj[c])[0]

df_values = pd.concat([df_numeric, df_obj], axis=1)

# %% [markdown]
# ### Dealing with missed variables

# %%
# from sklearn.base import TransformerMixin
# class DataFrameImputer(TransformerMixin):
#     def fit(self, X, y=None):
#         self.fill = pd.Series([X[c].value_counts().index[0]
#         if X[c].dtype == np.dtype('O') else X[c].median() for c in X],
#         index=X.columns)
#         return self
#     def transform(self, X, y=None):
#         return X.fillna(self.fill)
# df_values = DataFrameImputer().fit_transform(df_values)

# %%
# Convert to numpy values
X_all = df_values.values
print(X_all.shape)

X_train = X_all[:num_train]
X_test = X_all[num_train:]

df_columns = df_values.columns
# Out:
# (38133, 319)

# %% [markdown]
# ## Stacking

# %%
n_folds = 5
stacker = xgb.XGBRegressor(max_depth=6, nthread=4, subsample=0.8, objective='reg:linear', learning_rate=0.05,
                               colsample_bytree=0.8, n_estimators=400, seed=0)
base_models = {xgb.XGBRegressor(max_depth=5, nthread=4, subsample=0.7, objective='reg:linear', learning_rate=0.05,
                               colsample_bytree=0.7, n_estimators=500, seed=0)}

# %%
for i in range(10):
    base_models.add(xgb.XGBRegressor(max_depth=5, nthread=4, subsample=0.7, objective='reg:linear', learning_rate=0.05,
                               colsample_bytree=0.7, n_estimators=500, seed=i+1))

# %%
for i in range(10):
    base_models.add(xgb.XGBRegressor(max_depth=6, nthread=4, subsample=0.8, objective='reg:linear', learning_rate=0.05,
                               colsample_bytree=0.8, n_estimators=400, seed=i+50))

# %%
for i in range(10):
    base_models.add(xgb.XGBRegressor(max_depth=5, nthread=4, subsample=0.8, objective='reg:linear', learning_rate=0.05,
                               colsample_bytree=0.8, n_estimators=500, seed=i+100))

# %%
X = X_train
y = y_train
T = X_test
kf = model_selection.KFold(n_splits=n_folds, shuffle=True, random_state=2017)
S_train = np.zeros((X.shape[0], len(base_models)))
S_test = np.zeros((T.shape[0], len(base_models)))

# %%
for i, clf in enumerate(base_models):
    print clf
    S_test_i = np.zeros((T.shape[0], n_folds))
    for j, (train_idx, test_idx) in enumerate(kf.split(X, y)):
        X_train = X[train_idx]
        y_train = y[train_idx]
        X_holdout = X[test_idx]
        # y_holdout = y[test_idx]
        # %time clf.fit(X_train, y_train)
        y_pred = clf.predict(X_holdout)[:]
        S_train[test_idx, i] = y_pred
        S_test_i[:, j] = clf.predict(T)[:]
    S_test[:, i] = S_test_i.mean(1)
print stacker
# %time stacker.fit(S_train, y)
y_pred = stacker.predict(S_test)[:]
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=101, silent=True, subsample=0.8)
# CPU times: user 2min, sys: 1.1 s, total: 2min 1s
# Wall time: 31.9 s
# CPU times: user 2min 4s, sys: 951 ms, total: 2min 5s
# Wall time: 32.6 s
# CPU times: user 2min 9s, sys: 895 ms, total: 2min 10s
# Wall time: 33.9 s
# CPU times: user 2min 13s, sys: 952 ms, total: 2min 14s
# Wall time: 34.9 s
# CPU times: user 2min 20s, sys: 1 s, total: 2min 21s
# Wall time: 36.7 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=102, silent=True, subsample=0.8)
# CPU times: user 2min 25s, sys: 1.04 s, total: 2min 26s
# Wall time: 37.9 s
# CPU times: user 2min 26s, sys: 1.08 s, total: 2min 27s
# Wall time: 38.4 s
# CPU times: user 2min 30s, sys: 1.09 s, total: 2min 32s
# Wall time: 39.5 s
# CPU times: user 2min 30s, sys: 1.14 s, total: 2min 31s
# Wall time: 39.4 s
# CPU times: user 2min 32s, sys: 1.12 s, total: 2min 33s
# Wall time: 40 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=6, silent=True, subsample=0.7)
# CPU times: user 2min 19s, sys: 1.11 s, total: 2min 21s
# Wall time: 36.8 s
# CPU times: user 2min 19s, sys: 1.11 s, total: 2min 20s
# Wall time: 36.7 s
# CPU times: user 2min 19s, sys: 1.11 s, total: 2min 20s
# Wall time: 36.7 s
# CPU times: user 2min 20s, sys: 1.14 s, total: 2min 21s
# Wall time: 36.9 s
# CPU times: user 2min 25s, sys: 1.1 s, total: 2min 26s
# Wall time: 38.1 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=7, silent=True, subsample=0.7)
# CPU times: user 2min 19s, sys: 1.11 s, total: 2min 21s
# Wall time: 36.8 s
# CPU times: user 2min 21s, sys: 1.13 s, total: 2min 22s
# Wall time: 37.1 s
# CPU times: user 2min 20s, sys: 1.11 s, total: 2min 21s
# Wall time: 36.9 s
# CPU times: user 2min 19s, sys: 1.13 s, total: 2min 21s
# Wall time: 36.8 s
# CPU times: user 2min 20s, sys: 1.12 s, total: 2min 21s
# Wall time: 36.9 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=107, silent=True, subsample=0.8)
# CPU times: user 2min 36s, sys: 1.16 s, total: 2min 37s
# Wall time: 41 s
# CPU times: user 2min 35s, sys: 1.13 s, total: 2min 36s
# Wall time: 40.6 s
# CPU times: user 2min 35s, sys: 1.14 s, total: 2min 36s
# Wall time: 40.7 s
# CPU times: user 2min 35s, sys: 1.16 s, total: 2min 36s
# Wall time: 40.7 s
# CPU times: user 2min 35s, sys: 1.13 s, total: 2min 36s
# Wall time: 40.7 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=105, silent=True, subsample=0.8)
# CPU times: user 2min 37s, sys: 1.15 s, total: 2min 38s
# Wall time: 41.2 s
# CPU times: user 2min 35s, sys: 1.14 s, total: 2min 36s
# Wall time: 40.8 s
# CPU times: user 2min 36s, sys: 1.14 s, total: 2min 37s
# Wall time: 41 s
# CPU times: user 2min 36s, sys: 1.16 s, total: 2min 37s
# Wall time: 40.9 s
# CPU times: user 2min 35s, sys: 1.14 s, total: 2min 36s
# Wall time: 40.8 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=106, silent=True, subsample=0.8)
# CPU times: user 2min 37s, sys: 1.17 s, total: 2min 38s
# Wall time: 41.2 s
# CPU times: user 2min 36s, sys: 1.15 s, total: 2min 37s
# Wall time: 40.9 s
# CPU times: user 2min 36s, sys: 1.15 s, total: 2min 38s
# Wall time: 41 s
# CPU times: user 2min 37s, sys: 1.17 s, total: 2min 38s
# Wall time: 41.2 s
# CPU times: user 2min 38s, sys: 1.15 s, total: 2min 39s
# Wall time: 41.3 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=10, silent=True, subsample=0.7)
# CPU times: user 2min 24s, sys: 1.16 s, total: 2min 25s
# Wall time: 38 s
# CPU times: user 2min 21s, sys: 1.12 s, total: 2min 23s
# Wall time: 37.3 s
# CPU times: user 2min 23s, sys: 1.14 s, total: 2min 24s
# Wall time: 37.7 s
# CPU times: user 2min 21s, sys: 1.15 s, total: 2min 22s
# Wall time: 37.3 s
# CPU times: user 2min 21s, sys: 1.12 s, total: 2min 22s
# Wall time: 37.3 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=2, silent=True, subsample=0.7)
# CPU times: user 2min 22s, sys: 1.15 s, total: 2min 23s
# Wall time: 37.5 s
# CPU times: user 2min 21s, sys: 1.17 s, total: 2min 22s
# Wall time: 37.3 s
# CPU times: user 2min 22s, sys: 1.16 s, total: 2min 23s
# Wall time: 37.3 s
# CPU times: user 2min 22s, sys: 1.18 s, total: 2min 23s
# Wall time: 37.4 s
# CPU times: user 2min 24s, sys: 1.16 s, total: 2min 26s
# Wall time: 38 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=108, silent=True, subsample=0.8)
# CPU times: user 2min 38s, sys: 1.16 s, total: 2min 39s
# Wall time: 41.4 s
# CPU times: user 2min 37s, sys: 1.16 s, total: 2min 38s
# Wall time: 41.2 s
# CPU times: user 2min 38s, sys: 1.17 s, total: 2min 39s
# Wall time: 41.5 s
# CPU times: user 2min 37s, sys: 1.18 s, total: 2min 38s
# Wall time: 41.3 s
# CPU times: user 2min 37s, sys: 1.14 s, total: 2min 39s
# Wall time: 41.3 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=109, silent=True, subsample=0.8)
# CPU times: user 2min 38s, sys: 1.17 s, total: 2min 39s
# Wall time: 41.3 s
# CPU times: user 2min 36s, sys: 1.15 s, total: 2min 37s
# Wall time: 40.9 s
# CPU times: user 2min 35s, sys: 1.14 s, total: 2min 37s
# Wall time: 40.8 s
# CPU times: user 2min 36s, sys: 1.16 s, total: 2min 37s
# Wall time: 40.9 s
# CPU times: user 2min 36s, sys: 1.13 s, total: 2min 37s
# Wall time: 40.8 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=1, silent=True, subsample=0.7)
# CPU times: user 2min 21s, sys: 1.13 s, total: 2min 22s
# Wall time: 37.2 s
# CPU times: user 2min 20s, sys: 1.12 s, total: 2min 22s
# Wall time: 37 s
# CPU times: user 2min 20s, sys: 1.11 s, total: 2min 21s
# Wall time: 36.8 s
# CPU times: user 2min 19s, sys: 1.13 s, total: 2min 20s
# Wall time: 36.6 s
# CPU times: user 2min 20s, sys: 1.12 s, total: 2min 21s
# Wall time: 36.9 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=57, silent=True, subsample=0.8)
# CPU times: user 2min 28s, sys: 1.28 s, total: 2min 29s
# Wall time: 39 s
# CPU times: user 2min 27s, sys: 1.25 s, total: 2min 28s
# Wall time: 38.7 s
# CPU times: user 2min 28s, sys: 1.26 s, total: 2min 29s
# Wall time: 38.8 s
# CPU times: user 2min 26s, sys: 1.29 s, total: 2min 28s
# Wall time: 38.6 s
# CPU times: user 2min 25s, sys: 1.22 s, total: 2min 26s
# Wall time: 38.1 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=8, silent=True, subsample=0.7)
# CPU times: user 2min 24s, sys: 1.18 s, total: 2min 25s
# Wall time: 38.2 s
# CPU times: user 2min 14s, sys: 1.07 s, total: 2min 15s
# Wall time: 35.4 s
# CPU times: user 2min 14s, sys: 1.05 s, total: 2min 15s
# Wall time: 35.4 s
# CPU times: user 2min 15s, sys: 1.09 s, total: 2min 16s
# Wall time: 35.7 s
# CPU times: user 2min 15s, sys: 1.06 s, total: 2min 16s
# Wall time: 35.6 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=59, silent=True, subsample=0.8)
# CPU times: user 2min 24s, sys: 1.21 s, total: 2min 25s
# Wall time: 37.8 s
# CPU times: user 2min 23s, sys: 1.23 s, total: 2min 25s
# Wall time: 37.8 s
# CPU times: user 2min 23s, sys: 1.22 s, total: 2min 24s
# Wall time: 37.7 s
# CPU times: user 2min 26s, sys: 1.3 s, total: 2min 27s
# Wall time: 38.5 s
# CPU times: user 2min 24s, sys: 1.21 s, total: 2min 25s
# Wall time: 37.8 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=103, silent=True, subsample=0.8)
# CPU times: user 2min 30s, sys: 1.1 s, total: 2min 31s
# Wall time: 39.3 s
# CPU times: user 2min 44s, sys: 1.29 s, total: 2min 45s
# Wall time: 43.1 s
# CPU times: user 2min 37s, sys: 1.21 s, total: 2min 38s
# Wall time: 41.3 s
# CPU times: user 2min 37s, sys: 1.23 s, total: 2min 38s
# Wall time: 41.2 s
# CPU times: user 2min 34s, sys: 1.15 s, total: 2min 35s
# Wall time: 40.4 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=55, silent=True, subsample=0.8)
# CPU times: user 2min 23s, sys: 1.23 s, total: 2min 24s
# Wall time: 37.5 s
# CPU times: user 2min 24s, sys: 1.27 s, total: 2min 25s
# Wall time: 37.9 s
# CPU times: user 2min 22s, sys: 1.19 s, total: 2min 23s
# Wall time: 37.3 s
# CPU times: user 2min 23s, sys: 1.25 s, total: 2min 24s
# Wall time: 37.7 s
# CPU times: user 2min 21s, sys: 1.2 s, total: 2min 23s
# Wall time: 37.3 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=51, silent=True, subsample=0.8)
# CPU times: user 2min 21s, sys: 1.2 s, total: 2min 22s
# Wall time: 37.2 s
# CPU times: user 2min 21s, sys: 1.19 s, total: 2min 22s
# Wall time: 37 s
# CPU times: user 2min 21s, sys: 1.19 s, total: 2min 22s
# Wall time: 37 s
# CPU times: user 2min 20s, sys: 1.2 s, total: 2min 22s
# Wall time: 37 s
# CPU times: user 2min 20s, sys: 1.17 s, total: 2min 21s
# Wall time: 36.9 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=4, silent=True, subsample=0.7)
# CPU times: user 2min 12s, sys: 1.04 s, total: 2min 13s
# Wall time: 34.7 s
# CPU times: user 2min 9s, sys: 1.01 s, total: 2min 10s
# Wall time: 34 s
# CPU times: user 2min 9s, sys: 1.02 s, total: 2min 10s
# Wall time: 34.1 s
# CPU times: user 2min 10s, sys: 1.03 s, total: 2min 11s
# Wall time: 34.3 s
# CPU times: user 2min 11s, sys: 1.02 s, total: 2min 12s
# Wall time: 34.4 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=52, silent=True, subsample=0.8)
# CPU times: user 2min 18s, sys: 1.18 s, total: 2min 19s
# Wall time: 36.3 s
# CPU times: user 2min 17s, sys: 1.15 s, total: 2min 18s
# Wall time: 36.1 s
# CPU times: user 2min 19s, sys: 1.18 s, total: 2min 20s
# Wall time: 36.5 s
# CPU times: user 2min 18s, sys: 1.19 s, total: 2min 19s
# Wall time: 36.3 s
# CPU times: user 2min 18s, sys: 1.15 s, total: 2min 19s
# Wall time: 36.3 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=0.7)
# CPU times: user 2min 10s, sys: 1.02 s, total: 2min 11s
# Wall time: 34.2 s
# CPU times: user 2min 8s, sys: 1.01 s, total: 2min 9s
# Wall time: 33.8 s
# CPU times: user 2min 9s, sys: 1 s, total: 2min 10s
# Wall time: 34 s
# CPU times: user 2min 8s, sys: 1.02 s, total: 2min 10s
# Wall time: 33.9 s
# CPU times: user 2min 9s, sys: 1 s, total: 2min 10s
# Wall time: 34.1 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=56, silent=True, subsample=0.8)
# CPU times: user 2min 18s, sys: 1.17 s, total: 2min 19s
# Wall time: 36.3 s
# CPU times: user 2min 18s, sys: 1.16 s, total: 2min 19s
# Wall time: 36.3 s
# CPU times: user 2min 19s, sys: 1.17 s, total: 2min 20s
# Wall time: 36.5 s
# CPU times: user 2min 18s, sys: 1.2 s, total: 2min 19s
# Wall time: 36.3 s
# CPU times: user 2min 18s, sys: 1.15 s, total: 2min 19s
# Wall time: 36.2 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=100, silent=True, subsample=0.8)
# CPU times: user 2min 23s, sys: 1.03 s, total: 2min 24s
# Wall time: 37.5 s
# CPU times: user 2min 23s, sys: 1.02 s, total: 2min 24s
# Wall time: 37.5 s
# CPU times: user 2min 23s, sys: 1.02 s, total: 2min 24s
# Wall time: 37.4 s
# CPU times: user 2min 22s, sys: 1.04 s, total: 2min 23s
# Wall time: 37.3 s
# CPU times: user 2min 23s, sys: 1.03 s, total: 2min 24s
# Wall time: 37.6 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=104, silent=True, subsample=0.8)
# CPU times: user 2min 23s, sys: 1.03 s, total: 2min 24s
# Wall time: 37.5 s
# CPU times: user 2min 22s, sys: 1.02 s, total: 2min 23s
# Wall time: 37.1 s
# CPU times: user 2min 23s, sys: 1.01 s, total: 2min 24s
# Wall time: 37.5 s
# CPU times: user 2min 22s, sys: 1.03 s, total: 2min 23s
# Wall time: 37.2 s
# CPU times: user 2min 21s, sys: 1 s, total: 2min 22s
# Wall time: 37 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=50, silent=True, subsample=0.8)
# CPU times: user 2min 26s, sys: 1.28 s, total: 2min 27s
# Wall time: 38.7 s
# CPU times: user 2min 17s, sys: 1.15 s, total: 2min 18s
# Wall time: 35.9 s
# CPU times: user 2min 18s, sys: 1.16 s, total: 2min 19s
# Wall time: 36.2 s
# CPU times: user 2min 18s, sys: 1.19 s, total: 2min 19s
# Wall time: 36.3 s
# CPU times: user 2min 17s, sys: 1.16 s, total: 2min 18s
# Wall time: 36.1 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=54, silent=True, subsample=0.8)
# CPU times: user 2min 17s, sys: 1.16 s, total: 2min 18s
# Wall time: 36.1 s
# CPU times: user 2min 16s, sys: 1.16 s, total: 2min 18s
# Wall time: 35.9 s
# CPU times: user 2min 18s, sys: 1.16 s, total: 2min 19s
# Wall time: 36.2 s
# CPU times: user 2min 16s, sys: 1.18 s, total: 2min 17s
# Wall time: 35.9 s
# CPU times: user 2min 17s, sys: 1.16 s, total: 2min 18s
# Wall time: 36.1 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=5, silent=True, subsample=0.7)
# CPU times: user 2min 9s, sys: 1.02 s, total: 2min 10s
# Wall time: 34.1 s
# CPU times: user 2min 9s, sys: 1.01 s, total: 2min 10s
# Wall time: 33.9 s
# CPU times: user 2min 8s, sys: 999 ms, total: 2min 9s
# Wall time: 33.7 s
# CPU times: user 2min 8s, sys: 1.03 s, total: 2min 9s
# Wall time: 33.8 s
# CPU times: user 2min 8s, sys: 1 s, total: 2min 9s
# Wall time: 33.8 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=3, silent=True, subsample=0.7)
# CPU times: user 2min 8s, sys: 997 ms, total: 2min 9s
# Wall time: 33.8 s
# CPU times: user 2min 7s, sys: 994 ms, total: 2min 8s
# Wall time: 33.6 s
# CPU times: user 2min 8s, sys: 1.01 s, total: 2min 9s
# Wall time: 33.7 s
# CPU times: user 2min 7s, sys: 1.02 s, total: 2min 8s
# Wall time: 33.4 s
# CPU times: user 2min 6s, sys: 997 ms, total: 2min 7s
# Wall time: 33.3 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=53, silent=True, subsample=0.8)
# CPU times: user 2min 16s, sys: 1.18 s, total: 2min 17s
# Wall time: 35.7 s
# CPU times: user 2min 16s, sys: 1.16 s, total: 2min 17s
# Wall time: 35.9 s
# CPU times: user 2min 16s, sys: 1.15 s, total: 2min 18s
# Wall time: 35.9 s
# CPU times: user 2min 16s, sys: 1.17 s, total: 2min 17s
# Wall time: 35.8 s
# CPU times: user 2min 17s, sys: 1.15 s, total: 2min 18s
# Wall time: 36 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=58, silent=True, subsample=0.8)
# CPU times: user 2min 16s, sys: 1.16 s, total: 2min 17s
# Wall time: 35.9 s
# CPU times: user 2min 16s, sys: 1.14 s, total: 2min 17s
# Wall time: 35.7 s
# CPU times: user 2min 17s, sys: 1.17 s, total: 2min 18s
# Wall time: 36.1 s
# CPU times: user 2min 16s, sys: 1.18 s, total: 2min 18s
# Wall time: 35.9 s
# CPU times: user 2min 17s, sys: 1.15 s, total: 2min 18s
# Wall time: 36 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=9, silent=True, subsample=0.7)
# CPU times: user 2min 7s, sys: 1 s, total: 2min 8s
# Wall time: 33.6 s
# CPU times: user 2min 7s, sys: 1 s, total: 2min 8s
# Wall time: 33.6 s
# CPU times: user 2min 7s, sys: 988 ms, total: 2min 8s
# Wall time: 33.6 s
# CPU times: user 2min 7s, sys: 1.01 s, total: 2min 8s
# Wall time: 33.5 s
# CPU times: user 2min 8s, sys: 994 ms, total: 2min 9s
# Wall time: 33.7 s
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=400, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=0.8)
# CPU times: user 30.7 s, sys: 846 ms, total: 31.6 s
# Wall time: 9.05 s

# %%
# y_pred = model.predict(dtest)
df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_pred})

# %%
# df_naiveXGB['price_doc'] = df_naiveXGB['price_doc'] * 0.9691 + 10.08
df_sub.to_csv('EnsembleSub.csv', index=False)

# %%
df_sub['price_doc'].mean()
# Out:
# 7684382.5

# %%
df_sub.head(5)
# Out:
#       id  price_doc
# 0  30474  5592616.5
# 1  30475  8541218.0
# 2  30476  5642737.5
# 3  30477  6183659.0
# 4  30478  5405800.0
